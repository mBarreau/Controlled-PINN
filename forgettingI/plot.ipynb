# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
data_pd = np.load('runs/primal_dual_20251110_143921/rel_l2.npy')
data_pi = np.load('runs/pi_20251110_012957/rel_l2.npy')
data_primal = np.load('runs/primal_20251110_215156/rel_l2.npy')

# %%
plt.boxplot([data_primal, data_pi], labels=["Primal", "PI"], showfliers=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x153b94610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x153b95f10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x153b8f990>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x153b97610>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x153ba0110>,
# ...
#  'means': []}
